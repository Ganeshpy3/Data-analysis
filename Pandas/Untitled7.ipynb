# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
pd.set_option("display.max_columns",61)

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
dfc=df.groupby("Country")

# %%
ind=dfc.get_group("India")

# %%
ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8403 entries, 6 to 64452
# Data columns (total 61 columns):
# Respondent                      8403 non-null int64
# MainBranch                      8384 non-null object
# Hobbyist                        8403 non-null object
# Age                             8403 non-null float64
# Age1stCode                      6912 non-null object
# CompFreq                        4261 non-null object
# CompTotal                       2681 non-null float64
# ConvertedComp                   2668 non-null float64
# Country                         8403 non-null object
# CurrencyDesc                    5135 non-null object
# CurrencySymbol                  5135 non-null object
# DatabaseDesireNextYear          5702 non-null object
# DatabaseWorkedWith              6134 non-null object
# DevType                         5625 non-null object
# EdLevel                         6873 non-null object
# Employment                      8323 non-null object
# ...

# %%
ind.describe()
# Out:
#          Respondent          Age     CompTotal  ConvertedComp  WorkWeekHrs
# count   8403.000000  8403.000000  2.681000e+03   2.668000e+03  4029.000000
# mean   34084.377722    27.403582  3.729985e+32   2.875127e+04    40.345247
# std    18565.156681     4.542650  1.931308e+34   9.301753e+04    16.752230
# min        7.000000     3.000000  0.000000e+00   0.000000e+00     1.000000
# 25%    18562.000000    25.000000  3.800000e+04   5.196000e+03    40.000000
# 50%    36750.000000    29.000000  3.600000e+05   1.005600e+04    40.000000
# 75%    49196.000000    29.000000  1.085000e+06   2.010000e+04    48.000000
# max    65590.000000    99.000000  1.000000e+36   1.800000e+06   168.000000

# %%
ind["Hobbyist"].value_counts()
# Out:
# Yes    6645
# No     1758
# Name: Hobbyist, dtype: int64

# %%
count={}
for i in ind["LanguageWorkedWith"]:
    if type(i)== type("hello"):
        val=i.split(";")
        for i in val:
            if i in count:
                count[i] +=1
            else:
                count[i]=1

# %%
print(count)
# Out:
# {'C#': 1319, 'HTML/CSS': 4316, 'PHP': 1902, 'Java': 3252, 'Python': 2670, 'JavaScript': 4451, 'SQL': 3409, 'TypeScript': 1387, 'C': 2389, 'C++': 2047, 'Bash/Shell/PowerShell': 1054, 'Perl': 130, 'Objective-C': 333, 'Swift': 376, 'VBA': 213, 'Assembly': 273, 'Kotlin': 512, 'Rust': 75, 'R': 292, 'Scala': 153, 'Ruby': 233, 'Go': 322, 'Dart': 361, 'Julia': 30, 'Haskell': 39}

# %%
count["Python"]
# Out:
# 2670

# %%
count["C"]
# Out:
# 2389

# %%
count["Java"]
# Out:
# 3252

# %%
def max_Val(dic):
    val=0
    for i in dic.keys():
        if dic[i]> val:
            val=dic[i]
            name=i
            
    return val,name

# %%
plan,cnt=max_Val(count)

# %%
count["Haskell"]
# Out:
# 39

# %%
plan
# Out:
# 4451

# %%
count
# Out:
# {'C#': 1319,
#  'HTML/CSS': 4316,
#  'PHP': 1902,
#  'Java': 3252,
#  'Python': 2670,
#  'JavaScript': 4451,
#  'SQL': 3409,
#  'TypeScript': 1387,
#  'C': 2389,
#  'C++': 2047,
#  'Bash/Shell/PowerShell': 1054,
#  'Perl': 130,
#  'Objective-C': 333,
#  'Swift': 376,
#  'VBA': 213,
#  'Assembly': 273,
#  'Kotlin': 512,
#  'Rust': 75,
#  'R': 292,
#  'Scala': 153,
#  'Ruby': 233,
#  'Go': 322,
#  'Dart': 361,
#  'Julia': 30,
#  'Haskell': 39}

# %%
pro=pd.DataFrame(count,index=["programming languages"])

# %%
pro=pro.transpose()

# %%
pro.sort_values("programming languages",ascending=True,inplace=True)

# %%
pro.plot(kind="Barh",figsize=(20,10),title="2020 stackoverflow data India")

# %%
ind
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 6               7                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# 57             58                     I am a developer by profession      Yes
# 62             63             I am a student who is learning to code      Yes
# 147           149                     I am a developer by profession      Yes
# 175           177                     I am a developer by profession      Yes
# 225           227                     I am a developer by profession      Yes
# 230           232             I am a student who is learning to code       No
# 232           234                     I am a developer by profession      Yes
# 266           268                     I am a developer by profession      Yes
# 272           274                     I am a developer by profession      Yes
# ...

# %%
count1={}
for i in df["LanguageWorkedWith"]:
    if type(i)== type("hello"):
        val=i.split(";")
        for i in val:
            if i in count1:
                count1[i] +=1
            else:
                count1[i]=1

# %%
worldpro=pd.DataFrame(count1,index=["programming languages"])

# %%
worldpro=worldpro.transpose()

# %%
worldpro.sort_values("programming languages",ascending=True,inplace=True)

# %%
worldpro.plot(kind="Barh",figsize=(20,10),title="2020 stackoverflow data world")

# %%
df["Country"].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
# France                                 1898
# Brazil                                 1818
# Netherlands                            1343
# Poland                                 1278
# Australia                              1208
# Spain                                  1161
# Italy                                  1117
# Russian Federation                     1092
# Sweden                                  886
# Pakistan                                809
# Turkey                                  777
# Israel                                  653
# Switzerland                             629
# Bangladesh                              609
# Romania                                 604
# Nigeria                                 593
# ...

# %%
df["EdLevel"].value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.462155
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.228309
# Some college/university study without earning a degree                                0.126047
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.083074
# Associate degree (A.A., A.S., etc.)                                                   0.032091
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.029427
# Primary/elementary school                                                             0.016385
# Professional degree (JD, MD, etc.)                                                    0.013930
# I never completed any formal education                                                0.008584
# Name: EdLevel, dtype: float64

# %%
ind["EdLevel"].value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.666085
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.208352
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.059654
# Some college/university study without earning a degree                                0.036665
# Primary/elementary school                                                             0.010476
# I never completed any formal education                                                0.008148
# Professional degree (JD, MD, etc.)                                                    0.005820
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.003783
# Associate degree (A.A., A.S., etc.)                                                   0.001018
# Name: EdLevel, dtype: float64
